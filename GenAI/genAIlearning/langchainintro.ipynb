# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.17

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")

# %% [markdown]
# ## GEnerative AI application with groq model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %% [markdown]
# ## Using GROQ

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"] = "GROQ_API_KEY"

# %%
init_chat_model("groq:groq-1.0-flash")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\HP\Documents\Coding journeys\GenAI\.venv\Lib\site-packages\langchain\chat_models\base.py:118, in _import_module(module, class_name)
#     117 try:
# --> 118     return importlib.import_module(module)
#     119 except ImportError as e:
#     120     # Extract package name from module path (e.g., "langchain_azure_ai.chat_models"
#     121     # becomes "langchain-azure-ai")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'langchain_groq'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 init_chat_model("groq:groq-1.0-flash")
#
# File c:\Users\HP\Documents\Coding journeys\GenAI\.venv\Lib\site-packages\langchain\chat_models\base.py:479, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     471     warnings.warn(
#     472         f"{config_prefix=} has been set but no fields are configurable. Set "
#     473         f"`configurable_fields=(...)` to specify the model params that are "
#     474         f"configurable.",
#     475         stacklevel=2,
#     476     )
#     478 if not configurable_fields:
# --> 479     return _init_chat_model_helper(
#     480         cast("str", model),
#     481         model_provider=model_provider,
#     482         **kwargs,
#     483     )
#     484 if model:
#     485     kwargs["model"] = model
#
# File c:\Users\HP\Documents\Coding journeys\GenAI\.venv\Lib\site-packages\langchain\chat_models\base.py:502, in _init_chat_model_helper(model, model_provider, **kwargs)
#     495 def _init_chat_model_helper(
#     496     model: str,
#     497     *,
#     498     model_provider: str | None = None,
#     499     **kwargs: Any,
#     500 ) -> BaseChatModel:
#     501     model, model_provider = _parse_model(model, model_provider)
# --> 502     creator_func = _get_chat_model_creator(model_provider)
#     503     return creator_func(model=model, **kwargs)
#
# File c:\Users\HP\Documents\Coding journeys\GenAI\.venv\Lib\site-packages\langchain\chat_models\base.py:158, in _get_chat_model_creator(provider)
#     156 pkg, class_name, creator_func = _BUILTIN_PROVIDERS[provider]
#     157 try:
# --> 158     module = _import_module(pkg, class_name)
#     159 except ImportError as e:
#     160     if provider != "ollama":
#
# File c:\Users\HP\Documents\Coding journeys\GenAI\.venv\Lib\site-packages\langchain\chat_models\base.py:127, in _import_module(module, class_name)
#     122 pkg = module.split(".", maxsplit=1)[0].replace("_", "-")
#     123 msg = (
#     124     f"Initializing {class_name} requires the {pkg} package. Please install it "
#     125     f"with `pip install {pkg}`"
#     126 )
# --> 127 raise ImportError(msg) from e
#
# ImportError: Initializing ChatGroq requires the langchain-groq package. Please install it with `pip install langchain-groq`
