# %% [markdown]
# # What are models
# The model components in the LangChain is a crucial part of the frameword, designed to facilitate interactions with various language models and embedding models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# LM returns text while enbedding models gives vectors as output
# Embedding models are used to do Sematic search - RAG based applications

# %% [markdown]
# Will interact with (closed source)openAI, claude, gemini and (open source)huggingface models

# %% [markdown]
# ## 1. Language models

# %% [markdown]
# ### Two types :
# 1. LLMs : general purpose modesl that is used for text generation. Thet take a string(or plain text) as input and returna string
# 2. Chat models : LMs that are specilized for conversational tesks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Where to find them
# Huggingface - the largest repository if open course LLMs
#
# Ways to use Open Source Models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Disadvantages :

# %% [markdown]
# ![image.png](attachment:image.png)
