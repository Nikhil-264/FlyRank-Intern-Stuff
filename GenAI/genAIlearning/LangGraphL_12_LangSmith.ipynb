# %% [markdown]
# # Why do we need LangSmith

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# LangSmith is a unified observabolity and evaluation platform where teams can debug, est and monitor AI app performance

# %% [markdown]
# #### What does LangSmith Trace?
# - Input and output
# - All the intermediate steps
# - Latency
# - token usage
# - Cost
# - Error
# - Tags
# - Metadata
# - Feedback

# %% [markdown]
# ## Core concepts

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
